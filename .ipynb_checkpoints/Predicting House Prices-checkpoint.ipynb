# %% [markdown]
# #  **Data Science Tutorial**

# %% [markdown]
# ![](https://res.cloudinary.com/startup-grind/image/upload/c_limit,dpr_2,f_auto,g_center,h_1440,q_auto:good,w_2048/v1/gcs/platform-data-dsc/chapter_photos/DSC_UG.png)

# %% [markdown]
# > This tutorial is to explain certain essential data science practices to improve Machine Learning Predictions

# %%
# This cell imports all the necessary libraries and methods
import pandas as pd
import numpy as np

# Visualisation libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the data
train_data = pd.read_csv('datasets/train.csv', index_col='Id')
X_test = pd.read_csv('datasets/test.csv', index_col='Id')

# %%
# Separate features from labels
y = train_data.SalePrice              
X_train = train_data.drop(['SalePrice'], axis=1)

# %% [markdown]
# # Models

# %% [markdown]
# **First look for suitable features which are strongly correlated with SalePrice**

# %%
# Correlation analysis
correlation_df = train_data.corr()

# Set font_scale
sns.set(font_scale=1.1)

# Set plot size
plt.figure(figsize=(20, 20))

# Define a mask to show only the upper triangular matrix of the correlation matrix
mask = np.triu(correlation_df.corr())

# Use a heatmap to analyse correlation
sns.heatmap(correlation_df,
            fmt='.1f',
            annot=True,
            cmap="coolwarm",
            square=True,
            mask=mask,
            linewidths=1,
            cbar=False)


# Show plot as a diagram rather than an object
plt.show()

# %%
# Concatenate features from both testing and training datasets
features = pd.concat([X_train, X_test]).reset_index(drop=True)
print(features.shape)
# Out:
# (2919, 79)

# %%
def missing_percentage(df):
    '''Return the number and percentage of missing values'''
    NaN_count = df.isnull().sum().sort_values(ascending=False)
    NaN_count = NaN_count[NaN_count!=0]
    
    NaN_percent = (NaN_count / len(df)) * 100
    
    NaN_info = pd.concat([NaN_count, NaN_percent], axis=1, keys=["Total", "Percent"])
    
    return NaN_info

# %%
missing = missing_percentage(features)

fig, ax = plt.subplots(figsize=(20, 5))

sns.barplot(x=missing.index, y="Percent", data=missing, palette="Reds_r")
plt.xticks(rotation="vertical")

plt.show()

missing = missing.T

display(missing.style.background_gradient(cmap="Reds", axis=1))
# Out:
# <style  type="text/css" >
#     #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col1 {
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col2 {
#             background-color:  #860811;
#             color:  #f1f1f1;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col3 {
#             background-color:  #b91419;
#             color:  #f1f1f1;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col4 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col5 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col6 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col7 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col8 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col9 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col10 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col11 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col12 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col13 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col14 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col15 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col16 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col17 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col18 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col19 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col20 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col21 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col22 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col23 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col24 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col25 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col26 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col27 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col28 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col29 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col30 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col31 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col32 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow0_col33 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col1 {
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col2 {
#             background-color:  #860811;
#             color:  #f1f1f1;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col3 {
#             background-color:  #b91419;
#             color:  #f1f1f1;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col4 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col5 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col6 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col7 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col8 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col9 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col10 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col11 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col12 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col13 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col14 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col15 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col16 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col17 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col18 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col19 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col20 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col21 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col22 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col23 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col24 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6ecd56f8_1d27_11eb_8f6b_dcf505828c7arow1_col25 {
#             background-color:  #

# %%
# Let't categorize the missing the features
# Some null values 
zero_cols = [col for col in missing.columns if (X_train[col].dtype!="O" and col!="LotFrontage")]
freq_cols = [col for col in missing.columns if (missing[col]["Total"]<=2 and col not in zero_cols)]
none_cols = [col for col in missing.columns if (X_train[col].dtype=="O" and col!="MSZoning")]


# Some N/A values mean that that particular house doesn't have the feature described (eg; A pool, an alley)
# In such cases, numerical values will be marked as 0 and categorical features will be categorized by a new class, None
# In cases where the null values occur in a few houses, it is possible that there're actual missing values
# In such cases, we will replace them with the mode

for col in zero_cols:
    features[col].replace(np.nan, 0, inplace=True)
    
for col in freq_cols:
    features[col].replace(np.nan, features[col].mode()[0], inplace=True)
    
for col in none_cols:
    features[col].replace(np.nan, "None", inplace=True)

# %%
# We can't replace all NaN values in the MSSubClass and LotFrontage
# with zeros (O can't be a reasonable prediction of the null values)
# We can use other features to make a fairly accurate estimation of the null values

# MSSubClass (the type of dwelling) may help predict the type of zone
features["MSZoning"] = features.groupby("MSSubClass")["MSZoning"].apply(lambda x:x.fillna(x.mode()[0]))

# Neighbourhood may help predict the LotFrontage
features["LotFrontage"] = features.groupby("Neighborhood")["LotFrontage"].apply(lambda x:x.fillna(x.median()))

# %%
# We must cast some features from numerical features to strings
# One example is the year sold, "YrSold": the model may look for unneccessary patterns between the size of the year
# as a number rather than considering it as a category

numerical_to_categorical = ["MSSubClass", "YrSold", "MoSold"]

for feature in numerical_to_categorical:
    features[feature] = features[feature].astype("str")

# %% [markdown]
# #   Feature Engineering

# %%
# Some featurs have some values which are less than 10
# If a feature has two or more of such values, we will place it the other list
# Then, we will classify those mini values together as Other' 

others = [feature for feature in features.columns if ((features[feature].value_counts()<10).sum() > 1) and (features[feature].dtype=="O")]

for col in others:
    indices = features[col].isin(features[col].value_counts()[features[col].value_counts()<10].index)
    features[col][indices] = "Other"

# %%
from matplotlib.ticker import MaxNLocator

# %%
def srt_box(y, df):
    
    '''A function for displaying categorical variables.'''
    
    fig, axes = plt.subplots(14, 3, figsize=(25, 80))
    axes = axes.flatten()

    for i, j in zip(df.select_dtypes(include=['object']).columns, axes):

        sortd = df.groupby([i])[y].median().sort_values(ascending=False)
        sns.boxplot(x=i,
                    y=y,
                    data=df,
                    palette='plasma',
                    order=sortd.index,
                    ax=j)
        j.tick_params(labelrotation=45)
        j.yaxis.set_major_locator(MaxNLocator(nbins=18))

        plt.tight_layout()

# %%
srt_box('SalePrice', train_data)

# %%
# Out:
# MSSubClass
# Utilities
# HouseStyle
# RoofStyle
# ExterCond
# Foundation
# BsmtCond
# HeatingQC
# Electrical
# GarageQual
# GarageCond
# PoolQC
# MiscFeature

# %%
features['Condition1'].value_counts()
# Out:
# Norm      2511
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# RRAe        28
# PosA        20
# Other       15
# Name: Condition1, dtype: int64
